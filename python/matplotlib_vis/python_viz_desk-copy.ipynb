# %% [markdown]
# # Visualizations in Python using Matplotlib
#
#
#
#
# Source: [Data Visualization with Python](https://github.com/rhiever/python-data-visualization-course#license-and-usage-terms)\
# Author:  [Randal S. Olson](http://www.randalolson.com/)\
# License: [CC BY 4.0](https://creativecommons.org/licenses/by/4.0/)
#
# ## Table of Contents
# * [Linear plots](#line)
# * [Legends](#legend)
# * [Vertical bar charts](#vertical_bar)
# * [Horizontal bar charts](#horizontal_bar)
# * [Pie charts](#pie)
# * [Scatter plots](#scatter)
# * [Histograms](#histogram)
# * [Box plots](#box)
# * [Subplots](#subplots)
# * [Legend outside of plot](#legend)
# * [Styles](#styles)
# * [For fun](#fun)
#
# ## Useful links
#
# * Matplotlib documentation
#     * https://matplotlib.org
# * Example plots and code
#     * https://matplotlib.org/stable/gallery
# * University Libraries Data Analysis, Visualisation, and Informatics Syndicate
#     * https://libraries.ou.edu/davis
# * University Libaries workshops and events
#     * https://libraries.ou.edu/calendar-node-field-event-date/month

# %%
# the use of an percent synbol is referred to as a magic for use in Huoyter notebooks
# This command will place the graphics in-line with the notebook 
# %matplotlib inline

# %%
# import libaries that are needed

import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# <a name="line"></a>
# ## Line plots
#
# matplotlib function: `plot(x,y)`
#
# `x`: x coord
# `y`: y coord

# %%
# Create the data to be ploted

x = np.linspace(0,20)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

# %%
# show x 

x
# Out:
# array([ 0.        ,  0.40816327,  0.81632653,  1.2244898 ,  1.63265306,
#         2.04081633,  2.44897959,  2.85714286,  3.26530612,  3.67346939,
#         4.08163265,  4.48979592,  4.89795918,  5.30612245,  5.71428571,
#         6.12244898,  6.53061224,  6.93877551,  7.34693878,  7.75510204,
#         8.16326531,  8.57142857,  8.97959184,  9.3877551 ,  9.79591837,
#        10.20408163, 10.6122449 , 11.02040816, 11.42857143, 11.83673469,
#        12.24489796, 12.65306122, 13.06122449, 13.46938776, 13.87755102,
#        14.28571429, 14.69387755, 15.10204082, 15.51020408, 15.91836735,
#        16.32653061, 16.73469388, 17.14285714, 17.55102041, 17.95918367,
#        18.36734694, 18.7755102 , 19.18367347, 19.59183673, 20.        ])

# %%
# plot the first data set x and y1 

plt.figure()

plt.plot(x, y1)

plt.show()

# %%
# plot the both data sets x and y1  x and y2 on the same plot

plt.figure()

plt.plot(x, y1)
plt.plot(x, y2)

plt.show()

# %% [markdown]
# ### Commonly used parameters:
#
# `color`: Set the color of the line.
#
# `linestyle`: Set the line style, e.g., solid, dashed, or none.
#
# `linewidth`: Set the line thickness
#
# `marker`: Set the marker style, e.g., circles, triangles, or none.
#
# `markersize`: Set the marker size.
#
# `label`: Set the label for the line that will show up in the legend.
#
# To change the size of the inline image with .figure
#
# * `plt.figure(figsize=(12,10))` where the dimensions are width and height
# or
# * `plt.figure(dpi=150)` where dpi is the dots per inch

# %%
# plt.figure()
# Show how adjust the size of the inline plot
#plt.figure(dpi= 150)
plt.figure(figsize=(12,10))


plt.plot(x, y1,
         color = 'purple',
         linestyle = '-',
         linewidth =4,
         marker = 's', 
         markersize = 6,
         label = 'y1')

plt.plot(x, y2,
         color = 'green',
         linestyle = '-',
         linewidth =2,
         marker = 'd', 
         markersize = 6,
         label = 'y2')

plt.show()

# %% [markdown]
# ## Legends
#
# matplotlib function: `legend()`
#
# ### Commonly used parameters:
#
# `loc`: location of where legend is placed in the plot
#
# #### values for `loc`
# * best
# * upper right
# * upper left
# * lower left
# * lower right
# * right
# * center left
# * center right
# * lower center
# * upper center
# * center

# %%
# plt.figure()
plt.figure(figsize=(12,10))


plt.plot(x, y1,
         color = 'purple',
         linestyle = '-',
         linewidth =4,
         marker = 's', 
         markersize = 6,
         label = 'y1')

plt.plot(x, y2,
         color = 'green',
         linestyle = '-',
         linewidth =2,
         marker = 'd', 
         markersize = 6,
         label = 'y2')

plt.legend(loc = 'best')

plt.show()

# %% [markdown]
# <a name="vertical_bar"></a>
# ## Vertical bar charts
#
# matplotlib function:`bar(x, height)`
#
# `x`: x coordiantes of bars
# `height`: height(s) of the bars

# %%
# Create the dataset to be loted
years = np.arange(2012, 2015)
values = [2,5,9]

# %%
plt.figure(dpi=120)

plt.bar(years, values)

plt.show()

# %% [markdown]
# ### Commonly used parameters:
#
# `color`: Set the color of the bars.
#
# `edgecolor`: Set the color of the lines on the edges of the bars.
#
# `width`: Set the width of the bars.
#
# `align`: Set the alignment of the bars, e.g., center them on the x coordinate(s).
#
# `label`: Set the label for the bar that will show up in the legend.

# %%
years = np.arange(2012, 2015)

category_1 = [2,5,9]
category_2 = [7, 6, 3]

# %%
plt.figure(dpi=120)

plt.bar(years -.2,category_1,
       color = 'orange',
       edgecolor = 'none',
       width = 0.4,
       align = 'center', 
       label = 'y1')

plt.bar(years +.2,category_2,
       color = 'blue',
       edgecolor = 'none',
       width = 0.4,
       align = 'center', 
       label = 'y2')

plt.xticks(years, [str(year) for year in years])

plt.legend()

plt.show()

# %% [markdown]
# <a name="horizontal_bar"></a>
# ## horizontal bar charts
#
# ```
# barh(y, width)
# ```
# `y`: y coordinates of the bars `width`: width(s) of the bars

# %%
categories = ["A","B","C","D","E"]
values = [7,12,4,2,9]

# %%
# Y axis ordered from A-E, top to bottom

plt.figure(dpi=130)

plt.barh(np.arange(len(categories)), values)

plt.yticks(np.arange(len(categories)), 
           ['Category {}'.format(x) for x in categories])

plt.show()

# %%
# Y axis ordered from E-A, top to bottom

plt.figure(dpi=130)

plt.barh(-np.arange(len(categories)), values,
        color = 'yellow',
        edgecolor = 'purple',
        height = 0.6,
        align = 'center')

plt.yticks(-np.arange(len(categories)), ['Category {}'.format(x) for x in categories])

plt.show()

# %%
# Sort according to size of values

# load pandas to make use of sort function
import pandas as pd

# Create dataframe
category_values = pd.DataFrame({'categories':categories,
                              'values':values})

# %%
category_values
# Out:
#   categories  values
# 0          A       7
# 1          B      12
# 2          C       4
# 3          D       2
# 4          E       9

# %%
category_values.sort_values(by='values', ascending = False, inplace = True)

categories = category_values['categories'].values
values = category_values['values'].values

# %%
plt.figure(dpi=130)

plt.barh(-np.arange(len(categories)), values,
        color = 'yellow',
        edgecolor = 'purple',
        height = 0.6,
        align = 'center')

plt.yticks(-np.arange(len(categories)), ['Category {}'.format(x) for x in categories])

plt.show()

# %% [markdown]
# <a name="pie"></a>
# ## Pie Charts
#
# matplotlib function: `pie(x)`
#
# `x` : wedge sizes

# %%
counts = [17,16, 9, 4, 1]

plt.figure(dpi=130)

plt.pie(counts)

plt.show()

# %% [markdown]
# ### Commonly used parameters:
#
# `colors`: Set the colors of the wedges.
#
# `labels`: Set the labels of the wedges.
#
# `startangle`: Set the angle that the wedges start at.
#
# `autopct`: Set the percentage display format of the wedges.

# %%
counts = [17,14]

plt.figure(figsize=(8,8))

plt.pie(counts, 
        colors = ['blue', 'orange'],
        labels = ['Category A', 'Category B'], 
                 startangle =90,
                 autopct='%1.1f%%')

plt.savefig('plots/pie_chart.pdf', dpi=150)

plt.show()

# %% [markdown]
# <a name="scatter"></a>
# ## Scater plots
#
# matplotlib function: `scatter(x, y)`
#
#
# `x`, `y`: The values for the two variables.

# %%
x = range(20)
y = np.arange(50,70) + (np.random.random(20) * 10)

# %%
plt.figure(dpi=130)
plt.scatter(x,y)

plt.show()

# %% [markdown]
# ### Commonly used parameters:
#
# `c`: Set the color of the markers.
#
# `s`: Set the size of the markers.
#
# `marker`: Set the marker style, e.g., circles, triangles, or squares.
#
# `edgecolor`: Set the color of the lines on the edges of the markers.

# %%
plt.figure(dpi=130)

plt.scatter(x, y,
           c = 'red',
           s = 40,
           marker = 's',
           edgecolor = 'none')

plt.show()

# %% [markdown]
# <a name="histogram"></a>
# ## Histograms
#
# Purpose: Showing the spread of a data column.
#
# matplotlib function: `hist(x)`
#
# `x`: List of values to display the distribution

# %%
# Create data

column_data = np.random.normal(42,3,1000)

# %%
plt.figure(dpi=130)

plt.hist(column_data)

plt.show()

# %% [markdown]
# ### Commonly used parameters:
#
# `color`: Set the color of the bars in the histogram.
#
# `bins`: Set the number of bins to display in the histogram, or specify specific bins.
#
# `density`: Indicate whether the bins should display fractions instead of counts.

# %%
plt.figure(dpi=130)

plt.hist(column_data,
        color = 'cyan',
        bins = 50,
        density=True)

plt.show()

# %% [markdown]
# <a name="box"></a>
# ## Box plots
#
# Purpose: Summarize the distribution of a data column.
#
# matplotlib function: `boxplot(x)`
#
# `x`: List of values (or list of lists of values) to display the distribution of.

# %%
# Create dataset

two_columns_data = [np.random.normal(57,3,1000),
                   np.random.normal(42,7,1000)]

# %%
plt.figure(figsize=(10,10))
plt.boxplot(two_columns_data)

plt.show()

# %% [markdown]
# ### Commonly used parameters:
#
# `labels`: Set the labels for the box plots.
#
# `notch`: Indicate whether notches should be created around the median.
#
# `bootstrap`: Indicate whether the notches around the median should be bootstrapped.

# %%
plt.figure(figsize=(10,10)) 
plt.boxplot(two_columns_data,
           labels=['A','B'],
           notch=True,
           bootstrap=10000)

plt.show()

# %% [markdown]
# <a name="subplots"></a>
# ## Subplots
#
# Purpose: Allows you to place multiple charts in a figure.
#
# matplotlib function: `subplot(nrows, ncols, plot_number)`
#
# `nrows`: The number of rows in the figure.
#
# `ncols`: The number of columns in the figure.
#
# `plot_number`: The placement of the chart (starts at 1).

# %%
plt.figure(dpi=130)

# Using the loop variable to set the position of each plot with Titles 

for i in range(1,7):
    plt.subplot(2,3,i)
    plt.title(i)
    plt.xticks([])
    plt.yticks([])
    
# This function helps to keep axis labels and tick values from ploting on top of each other. 

plt.tight_layout()

plt.show()

# %%
# Create dataset

dist1 = np.random.normal(42,7,1000)
dist2 = np.random.normal(59,3,1000)

# %%
plt.figure(figsize=(10,4))

# Position 1 is for the histogram 

plt.subplot(1,2,1)
plt.hist(dist1)
plt.title('dist1')
plt.xlabel('Range')
plt.ylabel('Values')

# Postition 2 is for the scatter

plt.subplot(1,2,2)
plt.scatter(dist1, dist2)
plt.title('Scatter plot')
plt.xlabel('dist1')
plt.ylabel('dist2')

plt.tight_layout()

plt.show()

# %%
years = np.arange(2010,2016)

plt.figure(dpi=130)


# Here new data for the plot is being created with each iteration of the loop. 
# And then it is ploted

for category_num in range(1,17):
    y_vals = np.arange(10,16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)

plt.ylim(10,19)
plt.xlim(2010,2015)
plt.xticks(years, [str(year) for year in years])
plt.title('Group growth over time')
plt.xlabel('Years')
plt.ylabel('Counts')

plt.show()

# %%
years = np.arange(2010,2016)

plt.figure(figsize=(12,12))

# Here the subplot location is using the loop variable to specify where in
# the grid the plot is to go.

for category_num in range(1,17):
    plt.subplot(6,3,category_num)
    y_vals = np.arange(10,16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)

# limit is used to keep each axis units in sync
    plt.ylim(10,18)
    
    plt.xticks(years, [str(year) for year in years])
    plt.title('Group {}'.format(category_num))
    
plt.tight_layout()

plt.show()

# %% [markdown]
# <a name="legend"></a>
# # Place legend outside of plot area

# %% [markdown]
# ## Plot legend under plot area

# %%
# Under plot area

years = np.arange(2010,2016)

plt.figure(figsize=(10,10))

for category_num in range(1,17):
    y_vals = np.arange(10,16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals, label = category_num)

plt.ylim(10,19)
plt.xlim(2010,2015)
plt.xticks(years, [str(year) for year in years])

plt.title('Legend under plot', fontsize= 18)
plt.ylabel('Counts', fontsize= 14)
plt.xlabel('Years', fontsize= 14)

plt.legend(bbox_to_anchor=(.5,-.1), loc = 'upper center', ncol = 8)

plt.savefig('plots/outside_legend01.png', dpi=150, bbox_inches='tight')

# %% [markdown]
# ## Place legend above plot area

# %%
# Plot ledgend above plot area

years = np.arange(2010,2016)

plt.figure(figsize=(10,8))

for category_num in range(1,17):
    y_vals = np.arange(10,16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals, label = category_num)

plt.ylim(10,19)
plt.xlim(2010,2015)
plt.xticks(years, [str(year) for year in years])

plt.title('Legend above plot', fontsize= 18)
plt.ylabel('Counts', fontsize= 14)
plt.xlabel('Years', fontsize= 14)

plt.legend(bbox_to_anchor=(.5,1.2), loc = 'upper center', ncol = 8)

plt.savefig('plots/outside_legend02.png', dpi=150, bbox_inches='tight')

# %% [markdown]
# ## Place legend right of plot area

# %%
years = np.arange(2010,2016)

plt.figure(figsize=(10,8))

for category_num in range(1,17):
    y_vals = np.arange(10,16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals, label = category_num)

plt.ylim(10,19)
plt.xlim(2010,2015)
plt.xticks(years, [str(year) for year in years])

plt.title('Legend right of plot', fontsize= 18)
plt.ylabel('Counts', fontsize= 14)
plt.xlabel('Years', fontsize= 14)

plt.legend(bbox_to_anchor=(1.05,1), loc = 'upper center', ncol = 1)

plt.savefig('plots/outside_legend03.png', dpi=150, bbox_inches='tight')

# %% [markdown]
# <a name="styles"></a>
# ## Styles
#
# matplotlib functions: `style.available`
# `style.context(style)`

# %%
# Create three datasets

x1_values = [2012,2013,2014,2015]
y1_values = [4.3,2.5,1.8,4.5]

x2_values = [2012,2013,2014,2015]
y2_values = [2.4,4.4,1.8,2.8]

x3_values = [2012,2013,2014,2015]
y3_values = [2,2,3,5]

# %%
# plot data

plt.figure(figsize=(10,8))

plt.plot(x1_values,y1_values,
        label='Python',
        lw = 3,
        color = 'red')
plt.plot(x2_values,y2_values,
        label='JavaScript',
        lw = 3)
plt.plot(x3_values,y3_values,
        label = 'R',
        lw = 3)

plt.xticks([2012,2013,2014,2015],['2012', '2013', '2014', '2015'] )
plt.yticks([1,2,3,4,5])

plt.xlim(2012,2015)
plt.ylim(0,6)

plt.xlabel('Year', fontsize=18)
plt.ylabel('Web Searches', fontsize = 18)

plt.legend(loc='upper center', ncol = 3, fontsize = 18)
plt.grid(True)

# plt.savefig('plots/web_search_01.png', dpi =150)

plt.show()

# %% [markdown]
# **Command to show what styles are install on a particular instance of Python**

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# **Ploting figure with a particular style**

# %%
plt.figure(figsize=(10,8))

with plt.style.context('ggplot'): 

    plt.plot(x1_values,y1_values,
            label='Python',
            lw = 3,
            color = 'red')
    plt.plot(x2_values,y2_values,
            label='JavaScript',
            lw = 3)
    plt.plot(x3_values,y3_values,
            label = 'R',
            lw = 3)

    plt.xticks([2012,2013,2014,2015],['2012', '2013', '2014', '2015'] )
    plt.yticks([1,2,3,4,5])

    plt.xlim(2012,2015)
    plt.ylim(0,6)

    plt.xlabel('Year', fontsize=18)
    plt.ylabel('Web Searches', fontsize = 18)

    plt.legend(loc='upper center', ncol = 3, fontsize = 18)
    plt.grid(True)

    plt.savefig('plots/web_search_05.png', dpi =150)
    
    plt.show()

# %%
# Plot examples of all the styles available as one plot

# %%
# create a list of matplotlib styles
style_list = plt.style.available

plt.figure(figsize=(14,25))

# now loop over the list of styles and use subplot to arange output

counter = 1 # initialize counter

for style in style_list:

    with plt.style.context(style): 
 
        plt.subplot(8,4,counter)
        plt.plot(x1_values,y1_values,
                label='Python',
                lw = 2,
                color = 'red')
        plt.plot(x2_values,y2_values,
                label='JavaScript',
                lw = 2)
        plt.plot(x3_values,y3_values,
                label = 'R',
                lw = 2)

        plt.xticks([2012,2013,2014,2015],['2012', '2013', '2014', '2015'] )
        plt.yticks([1,2,3,4,5])

        plt.xlim(2012,2015)
        plt.ylim(0,6)

        plt.xlabel('Year')
        plt.ylabel('Web Searches')
        plt.title(style)

        plt.legend(loc='upper center', ncol = 3, prop={'size': 6})
        plt.grid(True)
        
        counter += 1

plt.tight_layout()
plt.savefig('plots/styles.png', dpi =150)

plt.show()

# %% [markdown]
# <a name="fun"></a>
# # For fun (Optional)
#
# ## XKCD
#
# ![from xkcd.com](https://imgs.xkcd.com/comics/stove_ownership.png)
#
#
# matplotlib function: `xkcd()`
#
# This will have some issues running on jupyter.lib.ou.edu since not all the fonts were installed in order to dave space.

# %%
plt.figure(figsize=(10,8))

with plt.xkcd():
    

    plt.plot(x1_values,y1_values,
            label='Python',
            lw = 3,
            color = 'red')
    plt.plot(x2_values,y2_values,
            label='JavaScript',
            lw = 3)
    plt.plot(x3_values,y3_values,
            label = 'R',
            lw = 3)

    plt.xticks([2012,2013,2014,2015],['2012', '2013', '2014', '2015'] )
    plt.yticks([1,2,3,4,5])

    plt.xlim(2012,2015)
    plt.ylim(0,6)

    plt.xlabel('Year', fontsize=18)
    plt.ylabel('Web Searches', fontsize = 18)

    plt.legend(loc='upper center', ncol = 3, fontsize = 18)
    plt.grid(True)

    plt.savefig('plots/web_search_01.png', dpi =150)
